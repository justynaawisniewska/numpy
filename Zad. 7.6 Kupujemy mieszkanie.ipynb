# %%
import numpy_financial as npf
import matplotlib.pyplot as plt
import pylab



rate = 0.05
T=5
pmt = 0
pv = 120000
npf.fv(rate/12, T*12, pmt, -pv)
# Out:
# 154003.04142042142

# %%
freq = 12
rate_b = 0.12
monthly_capital = - npf.pmt(rate_b/freq, freq*5 ,0, 153153)
print(round(monthly_capital,2))
# Out:
# 1875.27

# %%
y = [npf.fv(0.05/12, i, 0, -120000) for i in range(61)]
plt.plot(y)


x=[npf.fv(0.12/12, i, -1875,25, 0) for i in range(61)]

pylab.plot(x)
plt.xlabel('Liczba okresow')
plt.ylabel('Wartosc')
pylab.show()
